# %%
pip install google-cloud-bigquery
# Out:
# Collecting google-cloud-bigquery
#   Downloading google_cloud_bigquery-3.17.2-py2.py3-none-any.whl (230 kB)
#      ------------------------------------ 230.3/230.3 kB 613.0 kB/s eta 0:00:00
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5
#   Downloading google_api_core-2.17.1-py3-none-any.whl (137 kB)
#      -------------------------------------- 137.0/137.0 kB 4.0 MB/s eta 0:00:00
# Collecting google-cloud-core<3.0.0dev,>=1.6.0
#   Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl (29 kB)
# Collecting google-resumable-media<3.0dev,>=0.6.0
#   Downloading google_resumable_media-2.7.0-py2.py3-none-any.whl (80 kB)
#      ---------------------------------------- 80.6/80.6 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0.0 in c:\users\shree\appdata\roaming\python\python311\site-packages (from google-cloud-bigquery) (23.2)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in c:\users\shree\appdata\roaming\python\python311\site-packages (from google-cloud-bigquery) (2.8.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.21.0 in c:\python311\lib\site-packages (from google-cloud-bigquery) (2.31.0)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2
#   Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl (228 kB)
#      -------------------------------------- 228.7/228.7 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery) (4.25.2)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in c:\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery) (2.27.0)
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.5.0-cp311-cp311-win_amd64.whl (27 kB)
# Requirement already satisfied: six>=1.5 in c:\python311\lib\site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python311\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\python311\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python311\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python311\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (2024.2.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\python311\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\python311\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\python311\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery) (4.9)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery) (0.5.1)
# Installing collected packages: googleapis-common-protos, google-crc32c, google-resumable-media, google-api-core, google-cloud-core, google-cloud-bigquery
# Successfully installed google-api-core-2.17.1 google-cloud-bigquery-3.17.2 google-cloud-core-2.4.1 google-crc32c-1.5.0 google-resumable-media-2.7.0 googleapis-common-protos-1.62.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install db-dtypes
# Out:
# Collecting db-dtypes
#   Downloading db_dtypes-1.2.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=17.0 in c:\users\shree\appdata\roaming\python\python311\site-packages (from db-dtypes) (23.2)
# Requirement already satisfied: pandas>=0.24.2 in c:\python311\lib\site-packages (from db-dtypes) (2.1.4)
# Collecting pyarrow>=3.0.0
#   Downloading pyarrow-15.0.0-cp311-cp311-win_amd64.whl (24.8 MB)
#      ---------------------------------------- 24.8/24.8 MB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.6 in c:\python311\lib\site-packages (from db-dtypes) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shree\appdata\roaming\python\python311\site-packages (from pandas>=0.24.2->db-dtypes) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python311\lib\site-packages (from pandas>=0.24.2->db-dtypes) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\python311\lib\site-packages (from pandas>=0.24.2->db-dtypes) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->db-dtypes) (1.16.0)
# Installing collected packages: pyarrow, db-dtypes
# Successfully installed db-dtypes-1.2.0 pyarrow-15.0.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pickleshare
# Out:
# Requirement already satisfied: pickleshare in c:\python311\lib\site-packages (0.7.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from google.cloud.bigquery import Client, QueryJobConfig
client = Client()

query = """SELECT 
    *
FROM
  `york-bb-cohort.bqml_sd.201705`"""
    
job = client.query(query)
df = job.to_dataframe()

# %% [markdown]
# pip install google-cloud-bigquery
# pip install db-dtypes

# %%
df.to_csv("201705.csv", index=False)

# %%
# %store df
# Out:
# Stored 'df' (DataFrame)

# %%
df
# Out:
#          visitorId  visitNumber     visitId  visitStartTime      date  \
# 0             <NA>            2  1493674498      1493674498  20170501
# 1             <NA>            1  1494878564      1494878564  20170515
# 2             <NA>            3  1494119756      1494119756  20170506
# 3             <NA>            1  1495392106      1495392106  20170521
# 4             <NA>            1  1495665290      1495665290  20170524
# ...            ...          ...         ...             ...       ...
# 1662709       <NA>            1  1495375035      1495375035  20170521
# 1662710       <NA>            1  1495779371      1495779371  20170525
# 1662711       <NA>            1  1494720602      1494720602  20170513
# 1662712       <NA>            1  1495467163      1495467163  20170522
# 1662713       <NA>            1  1496262154      1496262154  20170531
#
#                fullVisitorId userId channelGrouping  socialEngagementType  \
# 0        7249590725717016365   None        Referral  Not Socially Engaged
# 1        0660528557813939545   None  Organic Search  Not Socially Engaged
# 2        9677364119598232321   None        Referral  Not Socially Engaged
# 3        0665273959712930130   None  Organic Search  Not Socially Engaged
# 4         048988688905997429   None        Referral  Not Socially Engaged
# ...                      ...    ...             ...                   ...
# 1662709  0414439488051883536   None          Direct  Not Socially Engaged
# 1662710  2812595484178305952   None          Social  Not Socially Engaged
# 1662711  3877044839082702253   None  Organic Search  Not Socially Engaged
# 1662712  9035532937514733438   None        Referral  Not Socially Engaged
# 1662713  5407782304147198241   None  Organic Search  Not Socially Engaged
#
#          hitNumber  ...      subContinent        country  \
# 0               12  ...  Northern America  United States
# 1               13  ...  Northern America  United States
# 2               21  ...  Northern America  United States
# 3                2  ...  Northern America  United States
# 4                1  ...  Northern America  United States
# ...            ...  ...               ...            ...
# 1662709         17  ...  Northern America  United States
# 1662710         11  ...  Northern America  United States
# 1662711          1  ...  Northern America         Canada
# 1662712          1  ...  Northern America  United States
# 1662713         17  ...  Northern America  United States
#
#                                 region                              metro  \
# 0                           California  San Francisco-Oakland-San Jose CA
# 1        not available in demo dataset      not available in demo dataset
# 2                             New York                        New York NY
# 3        not available in demo dataset      not available in demo dataset
# 4                           California  San Francisco-Oakland-San Jose CA
# ...                                ...                                ...
# 1662709  not available in demo dataset      not available in demo dataset
# 1662710                     California  San Francisco-Oakland-San Jose CA
# 1662711                        Ontario                          (not set)
# 1662712                       New York                        New York NY
# 1662713                       New York                        New York NY
#
#                                   city                         cityId  \
# 0                        Mountain View  not available in demo dataset
# 1        not available in demo dataset  not available in demo dataset
# 2                             New York  not available in demo dataset
# 3        not available in demo dataset  not available in demo dataset
# 4                        San Francisco  not available in demo dataset
# ...                                ...                            ...
# 1662709  not available in demo dataset  not available in demo dataset
# 1662710                  Mountain View  not available in demo dataset
# 1662711                        Toronto  not available in demo dataset
# 1662712                       New York  not available in demo dataset
# 1662713                       New York  not available in demo dataset
#
#                networkDomain                       latitude  \
# 0                  (not set)  not available in demo dataset
# 1                  (not set)  not available in demo dataset
# 2                  (not set)  not available in demo dataset
# 3                    cox.net  not available in demo dataset
# 4                  (not set)  not available in demo dataset
# ...                      ...                            ...
# 1662709      unknown.unknown  not available in demo dataset
# 1662710  fusionbroadband.com  not available in demo dataset
# 1662711            (not set)  not available in demo dataset
# 1662712            (not set)  not available in demo dataset
# 1662713            (not set)  not available in demo dataset
#
#                              longitude                networkLocation
# 0        not available in demo dataset  not available in demo dataset
# 1        not available in demo dataset  not available in demo dataset
# 2        not available in demo dataset  not available in demo dataset
# 3        not available in demo dataset  not available in demo dataset
# 4        not available in demo dataset  not available in demo dataset
# ...                                ...                            ...
# 1662709  not available in demo dataset  not available in demo dataset
# 1662710  not available in demo dataset  not available in demo dataset
# 1662711  not available in demo dataset  not available in demo dataset
# 1662712  not available in demo dataset  not available in demo dataset
# 1662713  not available in demo dataset  not available in demo dataset
#
# [1662714 rows x 302 columns]
